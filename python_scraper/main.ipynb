# %%
import pandas as pd

# %%
thread0 = pd.read_csv('threads/0.csv')
thread0.head()
# Out:
#                     id           channel_id              author  \
# 0  1159782960627724349  1159491755469721611  568421780331692042
# 1  1159506556522606613  1159491755469721611  749314817449394186
# 2  1159506229488537620  1159491755469721611  568421780331692042
# 3  1159505315730046996  1159491755469721611  374663548174991362
# 4  1159505285874991134  1159491755469721611  374663548174991362
#
#                                              content  \
# 0  Ok so I confirmed that the proof with a differ...
# 1          Sending the txns did not change anything.
# 2  can't explain this. will get someone to invest...
# 3                          hmm ok so that part works
# 4  but i think thats probably the bug here for so...
#
#                           timestamp  \
# 0  2023-10-06 09:23:25.539000+00:00
# 1  2023-10-05 15:05:05.665000+00:00
# 2  2023-10-05 15:03:47.694000+00:00
# 3  2023-10-05 15:00:09.837000+00:00
# 4  2023-10-05 15:00:02.719000+00:00
#
# ...

# %%
thread0.describe()
# Out:
#                  id    channel_id        author  referenced_message
# count  1.900000e+01  1.900000e+01  1.900000e+01        4.000000e+00
# mean   1.159517e+18  1.159492e+18  5.534842e+17        1.159503e+18
# std    6.463340e+13  0.000000e+00  1.708076e+17        4.102720e+12
# min    1.159492e+18  1.159492e+18  3.746635e+17        1.159497e+18
# 25%    1.159499e+18  1.159492e+18  3.746635e+17        1.159503e+18
# 50%    1.159505e+18  1.159492e+18  5.684218e+17        1.159505e+18
# 75%    1.159505e+18  1.159492e+18  7.493148e+17        1.159505e+18
# max    1.159783e+18  1.159492e+18  7.493148e+17        1.159505e+18
